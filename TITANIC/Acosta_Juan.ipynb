# %%
import pandas as pd
df=pd.read_csv("/workspaces/Proyecto_Final_Grupo_9/TITANIC/test_Titanic.csv")
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
d={}
l=df["Pclass"]
lista=[]
for i in l:
    lista.append(i)
for i in lista:
    if i not in d:
        d[f"clase {i}"]=f"Tiene {lista.count(i)} personas"
d
# Out:
# {'clase 3': 'Tiene 218 personas',
#  'clase 2': 'Tiene 93 personas',
#  'clase 1': 'Tiene 107 personas'}

# %%
lista_edad=[]
lista_sex=[]
for i in df["Age"]:
    lista_edad.append(i)
for i in df["Sex"]:
    lista_sex.append(i)
edades_hombre=0
edades_mujer=0
for i in range(len(lista_edad)):
    if lista_sex[i]=="male":
        edades_hombre+=lista_edad[i]
    else:
        edades_mujer+=lista_edad[i]
edades_hombre= edades_hombre/lista_sex.count("male")
edades_mujer= edades_mujer/lista_sex.count("female")
d={}
d["Promedio_edad_mujer"]=edades_mujer
d["Promedio_edad_hombre"]=edades_hombre
d
# Out:
# {'Promedio_edad_mujer': 25.293355263157896,
#  'Promedio_edad_hombre': 23.33048872180451}
